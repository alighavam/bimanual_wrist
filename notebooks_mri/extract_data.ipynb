# %%
import os
import sys
sys.path.append('/Users/aghavamp/Desktop/Projects')
sys.path.append('/Users/aghavamp/Desktop/Projects/bimanual_wrist')
sys.path.append('/Users/aghavamp/Desktop/Projects/Functional_Fusion')
import getpass
import importlib
from tqdm import tqdm

import scipy.io as sio
import rsatoolbox as rsa
from rsatoolbox.io import spm as spm_io
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import surfAnalysisPy as surf
import SUITPy as suit
import nibabel as nb
import nitools as nt
from matplotlib.cm import ScalarMappable
import matplotlib.cm as cm
import matplotlib.colors as mcolors
from pathlib import Path
import seaborn as sns
import PcmPy as pcm
import Functional_Fusion.atlas_map as am
import Functional_Fusion.reliability as rel
import glob
import matplotlib.patches as patches

import utils
importlib.reload(utils)

# SET PATHS:
baseDir = os.path.join('/Users', getpass.getuser(), 'Desktop', 'Projects', 'bimanual_wrist', 'data', 'fMRI')
bidsDir = 'BIDS'
anatomicalDir = 'anatomicals'
freesurferDir = 'surfaceFreesurfer'
surfacewbDir = 'surfaceWB' 
behavDir = 'behavioural'
regDir = 'ROI'
atlasDir = '/Volumes/diedrichsen_data$/data/Atlas_templates/fs_LR_32'
analysisDir = os.path.join(os.path.dirname(os.path.dirname(baseDir)), 'analysis')

# %% [markdown]
# extract the region data and the descriptors for each subj and save it in analysis directory.

# %%
glm = 1
region_labels = [1, 2, 3, 4, 5, 6, 7, 8]
region_names = ['S1', 'M1', 'PMd', 'PMv', 'SMA', 'V1', 'SPLa', 'SPLp']
sn_list = [101,102,103,104,106,107,108,109,110,111,112,113,114,115]
# sn_list = [110]
hem = ['L','R']
atlas,_ = am.get_atlas('fs32k')

# Intrinsic ordering of the conditions:
extrinsic_names = ['lhand:0',  'lhand:60',  'lhand:120',  'lhand:180',  'lhand:240',  'lhand:300',
                   'rhand:0',  'rhand:60',  'rhand:120',  'rhand:180',  'rhand:240',  'rhand:300',
                   'bi:0_0',   'bi:0_60',   'bi:0_120',   'bi:0_180',   'bi:0_240',   'bi:0_300',
                   'bi:60_0',  'bi:60_60',  'bi:60_120',  'bi:60_180',  'bi:60_240',  'bi:60_300',
                   'bi:120_0', 'bi:120_60', 'bi:120_120', 'bi:120_180', 'bi:120_240', 'bi:120_300',
                   'bi:180_0', 'bi:180_60', 'bi:180_120', 'bi:180_180', 'bi:180_240', 'bi:180_300',
                   'bi:240_0', 'bi:240_60', 'bi:240_120', 'bi:240_180', 'bi:240_240', 'bi:240_300',
                   'bi:300_0', 'bi:300_60', 'bi:300_120', 'bi:300_180', 'bi:300_240', 'bi:300_300']

intrinsic_names = ['lhand:flx',     'lhand:flxup',    'lhand:extup',    'lhand:ext',    'lhand:extdn',    'lhand:flxdn',
                   'rhand:ext',     'rhand:extup',    'rhand:flxup',    'rhand:flx',    'rhand:flxdn',    'rhand:extdn',
                   'bi:flx_ext',    'bi:flx_extup',   'bi:flx_flxup',   'bi:flx_flx',   'bi:flx_flxdn',   'bi:flx_extdn',
                   'bi:flxup_ext',  'bi:flxup_extup', 'bi:flxup_flxup', 'bi:flxup_flx', 'bi:flxup_flxdn', 'bi:flxup_extdn',
                   'bi:extup_ext',  'bi:extup_extup', 'bi:extup_flxup', 'bi:extup_flx', 'bi:extup_flxdn', 'bi:extup_extdn',
                   'bi:ext_ext',    'bi:ext_extup',   'bi:ext_flxup',   'bi:ext_flx',   'bi:ext_flxdn',   'bi:ext_extdn',
                   'bi:extdn_ext',  'bi:extdn_extup', 'bi:extdn_flxup', 'bi:extdn_flx', 'bi:extdn_flxdn', 'bi:extdn_extdn',
                   'bi:flxdn_ext',  'bi:flxdn_extup', 'bi:flxdn_flxup', 'bi:flxdn_flx', 'bi:flxdn_flxdn', 'bi:flxdn_extdn']

cond_num_extrinsic_ordered = [0, 1, 2, 3, 4, 5,
                              9, 8, 7, 6, 11, 10,
                              15, 14, 13, 12, 17, 16,
                              21, 20, 19, 18, 23, 22,
                              27, 26, 25, 24, 29, 28,
                              33, 32, 31, 30, 35, 34,
                              39, 38, 37, 36, 41, 40,
                              45, 44, 43, 42, 47, 46]

cond_num = [0, 1, 4, 3, 5, 2, 
            9, 10, 7, 6, 8, 11,
            15, 16, 13, 12, 14, 17,
            21, 22, 19, 18, 20, 23,
            39, 40, 37, 36, 38, 41,
            33, 34, 31, 30, 32, 35,
            45, 46, 43, 42, 44, 47,
            27, 28, 25, 24, 26, 29]

# Create mapping dictionary
extrinsic_to_intrinsic = dict(zip(extrinsic_names, intrinsic_names))
extrinsic_to_number = dict(zip(extrinsic_names, cond_num))
extrinsic_to_extrinsic_ordered_number = dict(zip(extrinsic_names, cond_num_extrinsic_ordered))

for k, r in enumerate(region_labels):
    for j, h in enumerate(hem):
        beta = []
        beta_white = []
        cond_extrinsic_vec = []
        cond_intrinsic_vec = []
        cond_num_vec = []
        cond_num_vec_extrinsic = []
        part_vec = []
        subject = []
        for i, sn in enumerate(sn_list):
            regressor_info = pd.read_table(os.path.join(baseDir, f'glm{glm}', f's{sn}', 'reginfo.tsv'))
            partitions = regressor_info['run'].values.flatten()
            conds = regressor_info['name'].values.flatten()
            conds = np.array([cond.strip() for cond in np.array(conds)])

            # ==========================================
            # DATA EXTRACTION
            # ==========================================
            #  Define atlas map
            white = os.path.join(baseDir, surfacewbDir, f's{sn}', f's{sn}.{h}.white.32k.surf.gii') # Individual white surface
            pial = os.path.join(baseDir, surfacewbDir, f's{sn}', f's{sn}.{h}.pial.32k.surf.gii') # Invividual pial surface
            mask = os.path.join(baseDir, f'glm{glm}', f's{sn}', 'mask.nii') # Mask in functional space for that subject

            # File names for data extraction
            nii_names = sorted(glob.glob(os.path.join(baseDir, f'glm{glm}', f's{sn}', "beta_*.nii")))
            nii_names = nii_names[0:-10] # omit the constant regressors
            ResMS_name = [os.path.join(baseDir, f'glm{glm}', f's{sn}', 'ResMS.nii')]
            
            beta_tmp = []
            ResMS = []
            beta_white_tmp = []
            
            atlas_tmp = atlas.get_hemisphere(j)
            subatlas = atlas_tmp.get_subatlas_image(os.path.join(atlasDir,f'ROI.32k.{h}.label.gii'), value=r)
            amap = am.AtlasMapSurf(subatlas.vertex[0],white,pial,mask) # Atlas map
            # Compute the voxels in native space
            amap.build()
            
            # This extract all the relevant voxels in native space (use for RSA)
            ResMS = amap.extract_data_native(ResMS_name)
            beta_tmp = amap.extract_data_native(nii_names)
            beta_white_tmp = beta_tmp / np.sqrt(ResMS)
            idx_nan = np.isnan(beta_tmp).any(axis=0)
            beta_tmp = beta_tmp[:, ~idx_nan]
            beta_white_tmp = beta_white_tmp[:, ~idx_nan]

            # ========================================== 
            # store the data
            # ==========================================
            subject.append(sn)
            beta.append(beta_tmp)
            beta_white.append(beta_white_tmp)
            cond_extrinsic_vec.append(conds)
            part_vec.append(partitions)
            
            # Convert conditions vector to intrinsic names
            cond_intrinsic_vec.append(np.array([extrinsic_to_intrinsic[cond] for cond in conds]))

            # Convert conditions vector to numbers
            cond_num_vec.append(np.array([extrinsic_to_number[cond] for cond in conds]))
            cond_num_vec_extrinsic.append(np.array([extrinsic_to_extrinsic_ordered_number[cond] for cond in conds]))

            print(f'{region_names[k]}, hem{h}, s{sn}')

        # save the data of hem and region:
        # Convert to object array to handle different shapes
        beta_obj = np.empty(len(beta), dtype=object)
        for i in range(len(beta)):
            beta_obj[i] = beta[i]
        # Convert to object array for beta_white
        beta_white_obj = np.empty(len(beta_white), dtype=object)
        for i in range(len(beta_white)):
            beta_white_obj[i] = beta_white[i]

        np.savez(os.path.join(analysisDir, f'pwbeta_{region_names[k]}_{h}.npz'), 
                  beta=beta_obj, 
                  beta_white=beta_white_obj,
                  cond_extrinsic_vec=cond_extrinsic_vec, 
                  cond_intrinsic_vec=cond_intrinsic_vec,
                  cond_num_vec=cond_num_vec,
                  cond_num_vec_extrinsic=cond_num_vec_extrinsic,
                  part_vec=part_vec,
                  subject=subject)
# Out:
# S1, hemL, s101
# S1, hemL, s102
# S1, hemL, s103
# S1, hemL, s104
# S1, hemL, s106
# S1, hemL, s107
# S1, hemL, s108
# S1, hemL, s109
# S1, hemL, s110
# S1, hemL, s111
# S1, hemL, s112
# S1, hemL, s113
# S1, hemL, s114
# S1, hemL, s115
# S1, hemR, s101
# S1, hemR, s102
# S1, hemR, s103
# S1, hemR, s104
# S1, hemR, s106
# S1, hemR, s107
# S1, hemR, s108
# S1, hemR, s109
# S1, hemR, s110
# S1, hemR, s111
# S1, hemR, s112
# S1, hemR, s113
# S1, hemR, s114
# S1, hemR, s115
# M1, hemL, s101
# M1, hemL, s102
# M1, hemL, s103
# M1, hemL, s104
# M1, hemL, s106
# M1, hemL, s107
# M1, hemL, s108
# M1, hemL, s109
# M1, hemL, s110
# M1, hemL, s111
# M1, hemL, s112
# M1, hemL, s113
# M1, hemL, s114
# M1, hemL, s115
# M1, hemR, s101
# M1, hemR, s102
# M1, hemR, s103
# M1, hemR, s104
# M1, hemR, s106
# M1, hemR, s107
# M1, hemR, s108
# M1, hemR, s109
# M1, hemR, s110
# M1, hemR, s111
# M1, hemR, s112
# M1, hemR, s113
# M1, hemR, s114
# M1, hemR, s115
# PMd, hemL, s101
# PMd, hemL, s102
# PMd, hemL, s103
# PMd, hemL, s104
# PMd, hemL, s106
# PMd, hemL, s107
# PMd, hemL, s108
# PMd, hemL, s109
# PMd, hemL, s110
# PMd, hemL, s111
# PMd, hemL, s112
# PMd, hemL, s113
# PMd, hemL, s114
# PMd, hemL, s115
# PMd, hemR, s101
# PMd, hemR, s102
# PMd, hemR, s103
# PMd, hemR, s104
# PMd, hemR, s106
# PMd, hemR, s107
# PMd, hemR, s108
# PMd, hemR, s109
# PMd, hemR, s110
# PMd, hemR, s111
# PMd, hemR, s112
# PMd, hemR, s113
# PMd, hemR, s114
# PMd, hemR, s115
# PMv, hemL, s101
# PMv, hemL, s102
# PMv, hemL, s103
# PMv, hemL, s104
# PMv, hemL, s106
# PMv, hemL, s107
# PMv, hemL, s108
# PMv, hemL, s109
# PMv, hemL, s110
# PMv, hemL, s111
# PMv, hemL, s112
# PMv, hemL, s113
# PMv, hemL, s114
# PMv, hemL, s115
# PMv, hemR, s101
# PMv, hemR, s102
# PMv, hemR, s103
# PMv, hemR, s104
# PMv, hemR, s106
# PMv, hemR, s107
# PMv, hemR, s108
# PMv, hemR, s109
# PMv, hemR, s110
# PMv, hemR, s111
# PMv, hemR, s112
# PMv, hemR, s113
# PMv, hemR, s114
# PMv, hemR, s115
# SMA, hemL, s101
# SMA, hemL, s102
# SMA, hemL, s103
# SMA, hemL, s104
# SMA, hemL, s106
# SMA, hemL, s107
# SMA, hemL, s108
# SMA, hemL, s109
# SMA, hemL, s110
# SMA, hemL, s111
# SMA, hemL, s112
# SMA, hemL, s113
# SMA, hemL, s114
# SMA, hemL, s115
# SMA, hemR, s101
# SMA, hemR, s102
# SMA, hemR, s103
# SMA, hemR, s104
# SMA, hemR, s106
# SMA, hemR, s107
# SMA, hemR, s108
# SMA, hemR, s109
# SMA, hemR, s110
# SMA, hemR, s111
# SMA, hemR, s112
# SMA, hemR, s113
# SMA, hemR, s114
# SMA, hemR, s115
# V1, hemL, s101
# V1, hemL, s102
# V1, hemL, s103
# V1, hemL, s104
# V1, hemL, s106
# V1, hemL, s107
# V1, hemL, s108
# V1, hemL, s109
# V1, hemL, s110
# V1, hemL, s111
# V1, hemL, s112
# V1, hemL, s113
# V1, hemL, s114
# V1, hemL, s115
# V1, hemR, s101
# V1, hemR, s102
# V1, hemR, s103
# V1, hemR, s104
# V1, hemR, s106
# V1, hemR, s107
# V1, hemR, s108
# V1, hemR, s109
# V1, hemR, s110
# V1, hemR, s111
# V1, hemR, s112
# V1, hemR, s113
# V1, hemR, s114
# V1, hemR, s115
# SPLa, hemL, s101
# SPLa, hemL, s102
# SPLa, hemL, s103
# SPLa, hemL, s104
# SPLa, hemL, s106
# SPLa, hemL, s107
# SPLa, hemL, s108
# SPLa, hemL, s109
# SPLa, hemL, s110
# SPLa, hemL, s111
# SPLa, hemL, s112
# SPLa, hemL, s113
# SPLa, hemL, s114
# SPLa, hemL, s115
# SPLa, hemR, s101
# SPLa, hemR, s102
# SPLa, hemR, s103
# SPLa, hemR, s104
# SPLa, hemR, s106
# SPLa, hemR, s107
# SPLa, hemR, s108
# SPLa, hemR, s109
# SPLa, hemR, s110
# SPLa, hemR, s111
# SPLa, hemR, s112
# SPLa, hemR, s113
# SPLa, hemR, s114
# SPLa, hemR, s115
# SPLp, hemL, s101
# SPLp, hemL, s102
# SPLp, hemL, s103
# SPLp, hemL, s104
# SPLp, hemL, s106
# SPLp, hemL, s107
# SPLp, hemL, s108
# SPLp, hemL, s109
# SPLp, hemL, s110
# SPLp, hemL, s111
# SPLp, hemL, s112
# SPLp, hemL, s113
# SPLp, hemL, s114
# SPLp, hemL, s115
# SPLp, hemR, s101
# SPLp, hemR, s102
# SPLp, hemR, s103
# SPLp, hemR, s104
# SPLp, hemR, s106
# SPLp, hemR, s107
# SPLp, hemR, s108
# SPLp, hemR, s109
# SPLp, hemR, s110
# SPLp, hemR, s111
# SPLp, hemR, s112
# SPLp, hemR, s113
# SPLp, hemR, s114
# SPLp, hemR, s115
